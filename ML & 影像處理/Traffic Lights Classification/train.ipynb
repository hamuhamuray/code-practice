# %% [markdown]
# #### Dataset:
# 1. https://universe.roboflow.com/test-rwdsy/traffic-light-taiwan/dataset/1#
# 2. https://www.kaggle.com/datasets/munirntut/tn-tld

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("munirntut/tn-tld", output_dir = "./")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[4], line 4
#       1 import kagglehub
#       3 # Download latest version
# ----> 4 path = kagglehub.dataset_download("munirntut/tn-tld", output_dir = "./")
#       6 print("Path to dataset files:", path)
#
# File c:\Users\hamuh\AppData\Local\Programs\Python\Python312\Lib\site-packages\kagglehub\datasets.py:52, in dataset_download(handle, path, force_download, output_dir)
#      50 h = parse_dataset_handle(handle)
#      51 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 52 resolved_path, _ = registry.dataset_resolver(
#      53     h,
#      54     path,
#      55     force_download=force_download,
#      56     output_dir=output_dir,
#      57 )
#      58 return resolved_path
#
# ...

# %%
from pathlib import Path

folder = r"./datasets/traffic-light-taiwan.v1i.yolov8/valid/labels"

mapping = {
    "1": "0",
    "2": "1",
    "0": "2"
}

for txt_file in Path(folder).glob("*.txt"):
    new_lines = []

    with open(txt_file, "r", encoding="utf-8") as f:
        for line in f:
            parts = line.strip().split()

            if not parts:
                continue

            if parts[0] in mapping:
                parts[0] = mapping[parts[0]]

            new_lines.append(" ".join(parts))

    with open(txt_file, "w", encoding="utf-8") as f:
        f.write("\n".join(new_lines))

print("完成")
# Out:
# 完成

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 4060

# %%
from ultralytics import YOLO

model = YOLO("yolo26s.pt")
print(model.ckpt["train_args"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 3
#       1 from ultralytics import YOLO
# ----> 3 model = YOLO("yolo26s.pt")
#       4 print(model.ckpt["train_args"])
#
# File c:\Users\hamuh\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\models\yolo\model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File c:\Users\hamuh\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\model.py:145, in Model.__init__(self, model, task, verbose)
#     143     self._new(model, task=task, verbose=verbose)
#     144 else:
# --> 145     self._load(model, task=task)
#
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolo8n.pt")
results = model.train(
    data="./datasets/munirntut/tn-tld/versions/2/tn-tld.yaml",
    epochs=100,
    imgsz=960,
    device=0,
    batch=16
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.81 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.23  Python-3.12.6 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
from ultralytics.utils import GIT
print(GIT.is_repo)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from ultralytics.utils import GIT
#       2 print(GIT.is_repo)
#
# ImportError: cannot import name 'GIT' from 'ultralytics.utils' (c:\Users\hamuh\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\utils\__init__.py)
